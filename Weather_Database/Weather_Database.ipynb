# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time


# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the G_Key
from config import g_key

# Import Google Maps
import gmaps

# %matplotlib inline

from ipywidgets.embed import embed_minimal_html

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # To get the response and print response
        #response = requests.get(city_url)
        #print(city_weather)
        #city_weather = response.json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_description})                                        

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

    #time.sleep(1)
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kurilsk
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | griffith
# Processing Record 10 of Set 1 | seymchan
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | hearst
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | statesboro
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | kruisfontein
# Processing Record 18 of Set 1 | mumford
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | lata
# Processing Record 21 of Set 1 | aklavik
# Processing Record 22 of Set 1 | aksay
# Processing Record 23 of Set 1 | bandarbeyla
# Processing Record 24 of Set 1 | necochea
# Processing Record 25 of Set 1 | jinchengjiang
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 1 | avera
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | abu dhabi
# Processing Record 31 of Set 1 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 1 | khandyga
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | barawe
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | cap malheureux
# Processing Record 47 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | cardinal
# Processing Record 50 of Set 1 | college
# Processing Record 1 of Set 2 | goundam
# Processing Record 2 of Set 2 | lasa
# Processing Record 3 of Set 2 | rock sound
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | bokspits
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 2 | san carlos del zulia
# Processing Record 7 of Set 2 | bandundu
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | north bend
# Processing Record 11 of Set 2 | storforshei
# Processing Record 12 of Set 2 | ribeirao
# Processing Record 13 of Set 2 | ozgon
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 2 | marzuq
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | muhos
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | wooster
# Processing Record 21 of Set 2 | waingapu
# Processing Record 22 of Set 2 | noumea
# Processing Record 23 of Set 2 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | goundi
# Processing Record 26 of Set 2 | juneau
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | cockburn town
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | pochutla
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | lakes entrance
# Processing Record 36 of Set 2 | riverton
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | ixtapa
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | nishihara
# Processing Record 41 of Set 2 | tarakan
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | balaipungut
# Processing Record 45 of Set 2 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | arlit
# Processing Record 48 of Set 2 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 2 | vila velha
# Processing Record 50 of Set 2 | charters towers
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | lubango
# Processing Record 4 of Set 3 | atherton
# Processing Record 5 of Set 3 | punta arenas
# Processing Record 6 of Set 3 | gaoyou
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | bosaso
# Processing Record 9 of Set 3 | deputatskiy
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | sayyan
# Processing Record 12 of Set 3 | jibuti
# Processing Record 13 of Set 3 | vangaindrano
# Processing Record 14 of Set 3 | shahpur
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | soritor
# Processing Record 17 of Set 3 | nadym
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | banda aceh
# Processing Record 20 of Set 3 | natal
# Processing Record 21 of Set 3 | kurumkan
# Processing Record 22 of Set 3 | malpe
# Processing Record 23 of Set 3 | rio grande
# Processing Record 24 of Set 3 | tingo maria
# Processing Record 25 of Set 3 | tiarei
# Processing Record 26 of Set 3 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 3 | matara
# Processing Record 28 of Set 3 | zhigansk
# Processing Record 29 of Set 3 | bacuit
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 3 | gornopravdinsk
# Processing Record 31 of Set 3 | oregon city
# Processing Record 32 of Set 3 | caiaponia
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | port macquarie
# Processing Record 35 of Set 3 | nanortalik
# Processing Record 36 of Set 3 | krasnaya zarya
# Processing Record 37 of Set 3 | pahrump
# Processing Record 38 of Set 3 | tambul
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 3 | ushtobe
# Processing Record 40 of Set 3 | ngawi
# Processing Record 41 of Set 3 | dolores
# Processing Record 42 of Set 3 | san luis
# Processing Record 43 of Set 3 | ambatofinandrahana
# Processing Record 44 of Set 3 | sibu
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | chapais
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | isangel
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | kollam
# Processing Record 4 of Set 4 | salekhard
# Processing Record 5 of Set 4 | stepnyak
# Processing Record 6 of Set 4 | makaryev
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | evanston
# Processing Record 9 of Set 4 | inhambane
# Processing Record 10 of Set 4 | gorno-chuyskiy
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 4 | kontagora
# Processing Record 12 of Set 4 | tornio
# Processing Record 13 of Set 4 | saint-augustin
# Processing Record 14 of Set 4 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | purpe
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | mogadishu
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | joao pinheiro
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | lilongwe
# Processing Record 25 of Set 4 | oksfjord
# Processing Record 26 of Set 4 | manokwari
# Processing Record 27 of Set 4 | walvis bay
# Processing Record 28 of Set 4 | svetlaya
# Processing Record 29 of Set 4 | grand gaube
# Processing Record 30 of Set 4 | alofi
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | coahuayana
# Processing Record 33 of Set 4 | lucea
# Processing Record 34 of Set 4 | mayo
# Processing Record 35 of Set 4 | moroni
# Processing Record 36 of Set 4 | la asuncion
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | srednekolymsk
# Processing Record 40 of Set 4 | arequipa
# Processing Record 41 of Set 4 | waipawa
# Processing Record 42 of Set 4 | rockhampton
# Processing Record 43 of Set 4 | kysyl-syr
# Processing Record 44 of Set 4 | mehamn
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | palmas del socorro
# Processing Record 47 of Set 4 | maceio
# Processing Record 48 of Set 4 | muros
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | port-gentil
# Processing Record 1 of Set 5 | jamestown
# Processing Record 2 of Set 5 | yacuiba
# Processing Record 3 of Set 5 | rio claro
# Processing Record 4 of Set 5 | beringovskiy
# Processing Record 5 of Set 5 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | tefe
# Processing Record 8 of Set 5 | codrington
# Processing Record 9 of Set 5 | cortez
# Processing Record 10 of Set 5 | marawi
# Processing Record 11 of Set 5 | sebrovo
# Processing Record 12 of Set 5 | christchurch
# Processing Record 13 of Set 5 | cabedelo
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | luganville
# Processing Record 16 of Set 5 | novi becej
# Processing Record 17 of Set 5 | labuhan
# Processing Record 18 of Set 5 | emerald
# Processing Record 19 of Set 5 | yongzhou
# Processing Record 20 of Set 5 | dalvik
# Processing Record 21 of Set 5 | kabanjahe
# Processing Record 22 of Set 5 | hualmay
# Processing Record 23 of Set 5 | dharchula
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | uwayl
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 5 | rafai
# Processing Record 30 of Set 5 | sitka
# Processing Record 31 of Set 5 | evensk
# Processing Record 32 of Set 5 | tautira
# Processing Record 33 of Set 5 | carupano
# Processing Record 34 of Set 5 | duz
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 5 | kerema
# Processing Record 36 of Set 5 | yining
# Processing Record 37 of Set 5 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 5 | carndonagh
# Processing Record 39 of Set 5 | bima
# Processing Record 40 of Set 5 | fairbanks
# Processing Record 41 of Set 5 | malureni
# Processing Record 42 of Set 5 | rorvik
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | northport
# Processing Record 46 of Set 5 | constanta
# Processing Record 47 of Set 5 | hovd
# Processing Record 48 of Set 5 | kyabe
# Processing Record 49 of Set 5 | todos santos
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | urdzhar
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 6 | los llanos de aridane
# Processing Record 4 of Set 6 | eyl
# Processing Record 5 of Set 6 | campo gobierno
# Processing Record 6 of Set 6 | colacling
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 6 | tahe
# Processing Record 8 of Set 6 | puerto ayora
# Processing Record 9 of Set 6 | narsaq
# Processing Record 10 of Set 6 | milledgeville
# Processing Record 11 of Set 6 | haines junction
# Processing Record 12 of Set 6 | port-cartier
# Processing Record 13 of Set 6 | magadan
# Processing Record 14 of Set 6 | kayerkan
# Processing Record 15 of Set 6 | ajaigarh
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | mrirt
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 6 | bedele
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | alice springs
# Processing Record 21 of Set 6 | kushima
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | smithers
# Processing Record 24 of Set 6 | houston
# Processing Record 25 of Set 6 | manavalakurichi
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | cidreira
# Processing Record 28 of Set 6 | tymovskoye
# Processing Record 29 of Set 6 | ucluelet
# Processing Record 30 of Set 6 | antofagasta
# Processing Record 31 of Set 6 | dolbeau
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 6 | ponta delgada
# Processing Record 33 of Set 6 | eirunepe
# Processing Record 34 of Set 6 | lebu
# Processing Record 35 of Set 6 | seabra
# Processing Record 36 of Set 6 | bull savanna
# Processing Record 37 of Set 6 | murshidabad
# Processing Record 38 of Set 6 | ajnala
# Processing Record 39 of Set 6 | faya
# Processing Record 40 of Set 6 | mattru
# Processing Record 41 of Set 6 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 6 | vengerovo
# Processing Record 43 of Set 6 | shushtar
# Processing Record 44 of Set 6 | luwuk
# Processing Record 45 of Set 6 | hithadhoo
# Processing Record 46 of Set 6 | hobyo
# Processing Record 47 of Set 6 | satipo
# Processing Record 48 of Set 6 | boende
# Processing Record 49 of Set 6 | skjervoy
# Processing Record 50 of Set 6 | helong
# Processing Record 1 of Set 7 | formoso do araguaia
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 7 | aykhal
# Processing Record 3 of Set 7 | foam lake
# Processing Record 4 of Set 7 | wasilla
# Processing Record 5 of Set 7 | atar
# Processing Record 6 of Set 7 | maldonado
# Processing Record 7 of Set 7 | kasongo-lunda
# Processing Record 8 of Set 7 | coquimbo
# Processing Record 9 of Set 7 | sioux lookout
# Processing Record 10 of Set 7 | bathsheba
# Processing Record 11 of Set 7 | cairns
# Processing Record 12 of Set 7 | kutum
# Processing Record 13 of Set 7 | tomatlan
# Processing Record 14 of Set 7 | saint-francois
# Processing Record 15 of Set 7 | temaraia
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 7 | naze
# Processing Record 17 of Set 7 | bubaque
# Processing Record 18 of Set 7 | gedo
# Processing Record 19 of Set 7 | thinadhoo
# Processing Record 20 of Set 7 | aldan
# Processing Record 21 of Set 7 | aleysk
# Processing Record 22 of Set 7 | cayenne
# Processing Record 23 of Set 7 | gao
# Processing Record 24 of Set 7 | buenos aires
# Processing Record 25 of Set 7 | udachnyy
# Processing Record 26 of Set 7 | caravelas
# Processing Record 27 of Set 7 | otjimbingwe
# Processing Record 28 of Set 7 | baykit
# Processing Record 29 of Set 7 | mount gambier
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | vestmanna
# Processing Record 32 of Set 7 | acari
# Processing Record 33 of Set 7 | mayor pablo lagerenza
# Processing Record 34 of Set 7 | madang
# Processing Record 35 of Set 7 | praia da vitoria
# Processing Record 36 of Set 7 | baghdad
# Processing Record 37 of Set 7 | qidong
# Processing Record 38 of Set 7 | ijaki
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 7 | rawson
# Processing Record 40 of Set 7 | vaitape
# Processing Record 41 of Set 7 | praia
# Processing Record 42 of Set 7 | grindavik
# Processing Record 43 of Set 7 | troitskoye
# Processing Record 44 of Set 7 | roald
# Processing Record 45 of Set 7 | maniitsoq
# Processing Record 46 of Set 7 | nuuk
# Processing Record 47 of Set 7 | diffa
# Processing Record 48 of Set 7 | fonte boa
# Processing Record 49 of Set 7 | colares
# Processing Record 50 of Set 7 | sola
# Processing Record 1 of Set 8 | san jose
# Processing Record 2 of Set 8 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 8 | prieska
# Processing Record 4 of Set 8 | chumikan
# Processing Record 5 of Set 8 | esik
# Processing Record 6 of Set 8 | lock haven
# Processing Record 7 of Set 8 | grootfontein
# Processing Record 8 of Set 8 | hamilton
# Processing Record 9 of Set 8 | doha
# Processing Record 10 of Set 8 | machalpur
# Processing Record 11 of Set 8 | havelock
# Processing Record 12 of Set 8 | pitimbu
# Processing Record 13 of Set 8 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 8 | wilson
# Processing Record 15 of Set 8 | kulachi
# Processing Record 16 of Set 8 | fairview
# Processing Record 17 of Set 8 | arman
# Processing Record 18 of Set 8 | taburi
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 8 | nizhnyaya poyma
# Processing Record 20 of Set 8 | vao
# Processing Record 21 of Set 8 | krasnoselkup
# Processing Record 22 of Set 8 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 8 | sahuaripa
# Processing Record 24 of Set 8 | shymkent
# Processing Record 25 of Set 8 | san patricio
# Processing Record 26 of Set 8 | potot
# Processing Record 27 of Set 8 | dudinka
# Processing Record 28 of Set 8 | barsi
# Processing Record 29 of Set 8 | ketchikan
# Processing Record 30 of Set 8 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 8 | abilene
# Processing Record 32 of Set 8 | pokrovsk
# Processing Record 33 of Set 8 | sokur
# Processing Record 34 of Set 8 | santiago
# Processing Record 35 of Set 8 | ambilobe
# Processing Record 36 of Set 8 | ossora
# Processing Record 37 of Set 8 | victor harbor
# Processing Record 38 of Set 8 | norden
# Processing Record 39 of Set 8 | ylivieska
# Processing Record 40 of Set 8 | athabasca
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | polovinnoye
# Processing Record 43 of Set 8 | iranshahr
# Processing Record 44 of Set 8 | eureka
# Processing Record 45 of Set 8 | bartica
# Processing Record 46 of Set 8 | ituporanga
# Processing Record 47 of Set 8 | igrim
# Processing Record 48 of Set 8 | caborca
# Processing Record 49 of Set 8 | saint joseph
# Processing Record 50 of Set 8 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 9 | chibuto
# Processing Record 2 of Set 9 | mago
# Processing Record 3 of Set 9 | qasigiannguit
# Processing Record 4 of Set 9 | stornoway
# Processing Record 5 of Set 9 | visby
# Processing Record 6 of Set 9 | saint anthony
# Processing Record 7 of Set 9 | westport
# Processing Record 8 of Set 9 | semnan
# Processing Record 9 of Set 9 | muscat
# Processing Record 10 of Set 9 | tahoua
# Processing Record 11 of Set 9 | yumen
# Processing Record 12 of Set 9 | brokopondo
# Processing Record 13 of Set 9 | nagapattinam
# Processing Record 14 of Set 9 | parksepa
# Processing Record 15 of Set 9 | sakakah
# Processing Record 16 of Set 9 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 9 | bojaya
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 9 | omsukchan
# Processing Record 19 of Set 9 | abu samrah
# Processing Record 20 of Set 9 | toropets
# Processing Record 21 of Set 9 | ancud
# Processing Record 22 of Set 9 | jacareacanga
# Processing Record 23 of Set 9 | jand
# Processing Record 24 of Set 9 | mocuba
# Processing Record 25 of Set 9 | seymour
# Processing Record 26 of Set 9 | shenzhen
# Processing Record 27 of Set 9 | maragogi
# Processing Record 28 of Set 9 | half moon bay
# Processing Record 29 of Set 9 | anadyr
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | jiazi
# Processing Record 32 of Set 9 | palmer
# Processing Record 33 of Set 9 | soure
# Processing Record 34 of Set 9 | berdigestyakh
# Processing Record 35 of Set 9 | huilong
# Processing Record 36 of Set 9 | souillac
# Processing Record 37 of Set 9 | ahipara
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | tshikapa
# Processing Record 40 of Set 9 | mazabuka
# Processing Record 41 of Set 9 | taltal
# Processing Record 42 of Set 9 | kungurtug
# Processing Record 43 of Set 9 | kentau
# Processing Record 44 of Set 9 | arcos
# Processing Record 45 of Set 9 | russell
# Processing Record 46 of Set 9 | malakal
# Processing Record 47 of Set 9 | metro
# Processing Record 48 of Set 9 | boquira
# Processing Record 49 of Set 9 | tual
# Processing Record 50 of Set 9 | husavik
# Processing Record 1 of Set 10 | lamar
# Processing Record 2 of Set 10 | buraydah
# Processing Record 3 of Set 10 | kirensk
# Processing Record 4 of Set 10 | lincoln
# Processing Record 5 of Set 10 | puerto escondido
# Processing Record 6 of Set 10 | manuk mangkaw
# Processing Record 7 of Set 10 | aliquippa
# Processing Record 8 of Set 10 | katsuura
# Processing Record 9 of Set 10 | tessalit
# Processing Record 10 of Set 10 | nioro
# Processing Record 11 of Set 10 | nabire
# Processing Record 12 of Set 10 | veraval
# Processing Record 13 of Set 10 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 10 | north vanlaiphai
# Processing Record 15 of Set 10 | richards bay
# Processing Record 16 of Set 10 | karla
# Processing Record 17 of Set 10 | fare
# Processing Record 18 of Set 10 | mulatupo
# Processing Record 19 of Set 10 | korla
# Processing Record 20 of Set 10 | kahului
# Processing Record 21 of Set 10 | malanje
# Processing Record 22 of Set 10 | boffa
# Processing Record 23 of Set 10 | koslan
# Processing Record 24 of Set 10 | boma
# Processing Record 25 of Set 10 | svetlogorsk
# Processing Record 26 of Set 10 | basco
# Processing Record 27 of Set 10 | sayat
# Processing Record 28 of Set 10 | horta
# Processing Record 29 of Set 10 | alenquer
# Processing Record 30 of Set 10 | mlonggo
# Processing Record 31 of Set 10 | setermoen
# Processing Record 32 of Set 10 | letlhakane
# Processing Record 33 of Set 10 | tungawan
# Processing Record 34 of Set 10 | batemans bay
# Processing Record 35 of Set 10 | vanavara
# Processing Record 36 of Set 10 | ambanja
# Processing Record 37 of Set 10 | khatanga
# Processing Record 38 of Set 10 | albanel
# Processing Record 39 of Set 10 | jamkhandi
# Processing Record 40 of Set 10 | churapcha
# Processing Record 41 of Set 10 | soyo
# Processing Record 42 of Set 10 | poum
# Processing Record 43 of Set 10 | chimore
# Processing Record 44 of Set 10 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 10 | dabola
# Processing Record 46 of Set 10 | videira
# Processing Record 47 of Set 10 | aktash
# Processing Record 48 of Set 10 | okhotsk
# Processing Record 49 of Set 10 | khormuj
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 10 | pala
# Processing Record 1 of Set 11 | marystown
# Processing Record 2 of Set 11 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 11 | chupei
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 11 | auki
# Processing Record 5 of Set 11 | quelimane
# Processing Record 6 of Set 11 | verkhnyaya inta
# Processing Record 7 of Set 11 | znamenskoye
# Processing Record 8 of Set 11 | hambantota
# Processing Record 9 of Set 11 | villa maria
# Processing Record 10 of Set 11 | sinnai
# Processing Record 11 of Set 11 | touros
# Processing Record 12 of Set 11 | zhigalovo
# Processing Record 13 of Set 11 | magugu
# Processing Record 14 of Set 11 | port blair
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | jumla
# Processing Record 17 of Set 11 | burnie
# Processing Record 18 of Set 11 | mount isa
# Processing Record 19 of Set 11 | urengoy
# Processing Record 20 of Set 11 | mahon
# Processing Record 21 of Set 11 | wajir
# Processing Record 22 of Set 11 | tilichiki
# Processing Record 23 of Set 11 | honiara
# Processing Record 24 of Set 11 | qazvin
# Processing Record 25 of Set 11 | sapao
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 11 | sao gabriel da cachoeira
# Processing Record 27 of Set 11 | roma
# Processing Record 28 of Set 11 | amga
# Processing Record 29 of Set 11 | jalu
# Processing Record 30 of Set 11 | lorengau
# Processing Record 31 of Set 11 | kanniyakumari
# Processing Record 32 of Set 11 | barra
# Processing Record 33 of Set 11 | wamba
# Processing Record 34 of Set 11 | halalo
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 11 | ariogala
# Processing Record 36 of Set 11 | savannakhet
# Processing Record 37 of Set 11 | hire
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 11 | tura
# Processing Record 39 of Set 11 | port lincoln
# Processing Record 40 of Set 11 | chimoio
# Processing Record 41 of Set 11 | mana
# Processing Record 42 of Set 11 | chai badan
# Processing Record 43 of Set 11 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 11 | tabas
# Processing Record 45 of Set 11 | montbrison
# Processing Record 46 of Set 11 | esso
# Processing Record 47 of Set 11 | monterey
# Processing Record 48 of Set 11 | turukhansk
# Processing Record 49 of Set 11 | nieuw amsterdam
# Processing Record 50 of Set 11 | franca
# Processing Record 1 of Set 12 | lao cai
# Processing Record 2 of Set 12 | luohe
# Processing Record 3 of Set 12 | campbell river
# Processing Record 4 of Set 12 | severo-yeniseyskiy
# Processing Record 5 of Set 12 | namibe
# Processing Record 6 of Set 12 | emba
# Processing Record 7 of Set 12 | qinhuangdao
# Processing Record 8 of Set 12 | meyungs
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 12 | mugur-aksy
# Processing Record 10 of Set 12 | acapulco
# Processing Record 11 of Set 12 | koudougou
# Processing Record 12 of Set 12 | clinton
# Processing Record 13 of Set 12 | upata
# Processing Record 14 of Set 12 | stoyba
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 12 | llallagua
# Processing Record 16 of Set 12 | ostuni
# Processing Record 17 of Set 12 | moron
# Processing Record 18 of Set 12 | lesnikovo
# Processing Record 19 of Set 12 | grenfell
# Processing Record 20 of Set 12 | bedford
# Processing Record 21 of Set 12 | hami
# Processing Record 22 of Set 12 | kirakira
# Processing Record 23 of Set 12 | jamalpur
# Processing Record 24 of Set 12 | murchison
# Processing Record 25 of Set 12 | kampot
# Processing Record 26 of Set 12 | villarrica
# Processing Record 27 of Set 12 | acuna
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 12 | ginda
# Processing Record 29 of Set 12 | komsomolskiy
# Processing Record 30 of Set 12 | yellamanchili
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 12 | laguna
# Processing Record 32 of Set 12 | axim
# Processing Record 33 of Set 12 | tortoli
# Processing Record 34 of Set 12 | jutai
# Processing Record 35 of Set 12 | verkhoyansk
# Processing Record 36 of Set 12 | pisco
# Processing Record 37 of Set 12 | palafrugell
# Processing Record 38 of Set 12 | telimele
# Processing Record 39 of Set 12 | yaan
# Processing Record 40 of Set 12 | linqu
# Processing Record 41 of Set 12 | ayan
# Processing Record 42 of Set 12 | gat
# Processing Record 43 of Set 12 | sinnamary
# Processing Record 44 of Set 12 | stephenville
# Processing Record 45 of Set 12 | baft
# Processing Record 46 of Set 12 | myitkyina
# Processing Record 47 of Set 12 | copiapo
# Processing Record 48 of Set 12 | launceston
# Processing Record 49 of Set 12 | deep river
# Processing Record 50 of Set 12 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 13 | la romana
# Processing Record 2 of Set 13 | vanimo
# Processing Record 3 of Set 13 | casper
# Processing Record 4 of Set 13 | bhinmal
# Processing Record 5 of Set 13 | nouakchott
# Processing Record 6 of Set 13 | joshimath
# Processing Record 7 of Set 13 | grajau
# Processing Record 8 of Set 13 | road town
# Processing Record 9 of Set 13 | gnjilane
# Processing Record 10 of Set 13 | vila do maio
# Processing Record 11 of Set 13 | pevek
# Processing Record 12 of Set 13 | kashi
# Processing Record 13 of Set 13 | dunedin
# Processing Record 14 of Set 13 | merauke
# Processing Record 15 of Set 13 | monrovia
# Processing Record 16 of Set 13 | bauchi
# Processing Record 17 of Set 13 | portland
# Processing Record 18 of Set 13 | takab
# Processing Record 19 of Set 13 | quatre cocos
# Processing Record 20 of Set 13 | bud
# Processing Record 21 of Set 13 | iracoubo
# Processing Record 22 of Set 13 | sochaczew
# Processing Record 23 of Set 13 | togur
# Processing Record 24 of Set 13 | krasnoarmeysk
# Processing Record 25 of Set 13 | madaba
# Processing Record 26 of Set 13 | bulnes
# Processing Record 27 of Set 13 | nara
# Processing Record 28 of Set 13 | tecoanapa
# Processing Record 29 of Set 13 | puerto el triunfo
# Processing Record 30 of Set 13 | khash
# Processing Record 31 of Set 13 | itaberai
# Processing Record 32 of Set 13 | yulara
# Processing Record 33 of Set 13 | rovaniemi
# Processing Record 34 of Set 13 | buckeye
# Processing Record 35 of Set 13 | ambon
# Processing Record 36 of Set 13 | caconda
# Processing Record 37 of Set 13 | miles city
# Processing Record 38 of Set 13 | alexandria
# Processing Record 39 of Set 13 | celestun
# Processing Record 40 of Set 13 | saint-georges
# Processing Record 41 of Set 13 | aksarka
# Processing Record 42 of Set 13 | pangkalanbuun
# Processing Record 43 of Set 13 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 13 | hagere hiywet
# Processing Record 45 of Set 13 | kroya
# Processing Record 46 of Set 13 | dhidhdhoo
# Processing Record 47 of Set 13 | severodvinsk
# Processing Record 48 of Set 13 | dickinson
# Processing Record 49 of Set 13 | taitung
# Processing Record 50 of Set 13 | sur
# Processing Record 1 of Set 14 | cockburn harbour
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 14 | mokhsogollokh
# Processing Record 3 of Set 14 | puerto madero
# Processing Record 4 of Set 14 | petauke
# Processing Record 5 of Set 14 | leningradskiy
# Processing Record 6 of Set 14 | ordu
# Processing Record 7 of Set 14 | samana
# Processing Record 8 of Set 14 | camacha
# Processing Record 9 of Set 14 | piranhas
# Processing Record 10 of Set 14 | dongli
# Processing Record 11 of Set 14 | gazojak
# Processing Record 12 of Set 14 | dalbandin
# Processing Record 13 of Set 14 | flinders
# Processing Record 14 of Set 14 | skibbereen
# Processing Record 15 of Set 14 | rio gallegos
# Processing Record 16 of Set 14 | flagstaff
# Processing Record 17 of Set 14 | kalmunai
# Processing Record 18 of Set 14 | camana
# Processing Record 19 of Set 14 | salcedo
# Processing Record 20 of Set 14 | havoysund
# Processing Record 21 of Set 14 | bitung
# Processing Record 22 of Set 14 | sibolga
# Processing Record 23 of Set 14 | madimba
# Processing Record 24 of Set 14 | killybegs
# Processing Record 25 of Set 14 | viligili
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 14 | pskov
# Processing Record 27 of Set 14 | sao jose da coroa grande
# Processing Record 28 of Set 14 | maumere
# Processing Record 29 of Set 14 | lima
# Processing Record 30 of Set 14 | alta floresta
# Processing Record 31 of Set 14 | dobson
# Processing Record 32 of Set 14 | sexsmith
# Processing Record 33 of Set 14 | ksenyevka
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 14 | olinda
# Processing Record 35 of Set 14 | collie
# Processing Record 36 of Set 14 | samalaeulu
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 14 | porto novo
# Processing Record 38 of Set 14 | mirina
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 14 | san miguel
# Processing Record 40 of Set 14 | bhavnagar
# Processing Record 41 of Set 14 | maloshuyka
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 14 | tukrah
# Processing Record 43 of Set 14 | norman
# Processing Record 44 of Set 14 | tamayong
# Processing Record 45 of Set 14 | cap-aux-meules
# Processing Record 46 of Set 14 | edea
# Processing Record 47 of Set 14 | mahibadhoo
# Processing Record 48 of Set 14 | tyup
# Processing Record 49 of Set 14 | carutapera
# Processing Record 50 of Set 14 | vila franca do campo
# Processing Record 1 of Set 15 | pringsewu
# Processing Record 2 of Set 15 | port hedland
# Processing Record 3 of Set 15 | vallenar
# Processing Record 4 of Set 15 | gorontalo
# Processing Record 5 of Set 15 | bagula
# Processing Record 6 of Set 15 | mackenzie
# Processing Record 7 of Set 15 | paita
# Processing Record 8 of Set 15 | maraa
# Processing Record 9 of Set 15 | kristinehamn
# Processing Record 10 of Set 15 | okha
# Processing Record 11 of Set 15 | pacific grove
# Processing Record 12 of Set 15 | karimpur
# Processing Record 13 of Set 15 | walkerburn
# Processing Record 14 of Set 15 | zhanaozen
# Processing Record 15 of Set 15 | lamu
# Processing Record 16 of Set 15 | aswan
# Processing Record 17 of Set 15 | zatoka
# Processing Record 18 of Set 15 | paamiut
# Processing Record 19 of Set 15 | nyurba
# Processing Record 20 of Set 15 | la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 663

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hobart      AU -42.8794  147.3294     46.26        76          90
# 1  Butaritari      KI   3.0707  172.7902     82.33        81         100
# 2     Mataura      NZ -46.1927  168.8643     49.48        97         100
# 3     Kurilsk      RU  45.2333  147.8833     42.78        96         100
# 4     Rikitea      PF -23.1203 -134.9692     77.00        85          72
# 5  Chokurdakh      RU  70.6333  147.9167     45.09        59           9
# 6   Cape Town      ZA -33.9258   18.4232     63.01        68          20
# 7      Atuona      PF  -9.8000 -139.0333     78.64        71          12
# 8    Griffith      US  41.5284  -87.4237     59.90        48           1
# 9    Seymchan      RU  62.8833  152.4333     37.85        72          13
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       15.86          light rain
# 2        3.49          light rain
# 3       14.25     overcast clouds
# 4       19.01       broken clouds
# 5        9.10           clear sky
# 6        1.99          few clouds
# 7       11.01          few clouds
# 8        5.99           clear sky
# 9        6.93          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
